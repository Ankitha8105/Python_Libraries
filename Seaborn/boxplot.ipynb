# %% [markdown]
# '''
#     @Author: Ankitha B L
#     @Date: 6-12-2024
#     @Last Modified by: Ankitha B L
#     @Last Modified time: 6-12-2024
#     @Title : python program for Seaborn Box plots
# '''

# %% [markdown]
# ### Q1. Write a program to draw box plot of life expectancy by continent for a data set

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
def draw_boxplot():
    """ 
    Description :
        This function is to draw box plot of life expectancy by continent for a data set
    Return :
        It returns box plot of life expectancy by continent for a data set
    """
    dataset = pd.read_csv('FiveYearData.csv')
    sns.catplot(x='continent',y='lifeExp',data=dataset,kind='box')
    
    
def main():
    draw_boxplot()
    
    
if __name__ == "__main__":
    main()

# %% [markdown]
# ### Q2. Write a program to draw a box plot of day by tips for a dataset

# %%
def generate_box_plot():
    """ 
    Description :
        This function is to draw a box plot of day by tips for a dataset
    Return :
        It returns box plot of day by tips for a dataset
    """
    dataset = pd.read_csv('tips.csv')
    sns.catplot(x='size',y='tip',data=dataset,kind='box')
    
    
def main():
    generate_box_plot()
    
    
if __name__ == "__main__":
    main()
