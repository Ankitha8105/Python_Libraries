# %% [markdown]
# '''
#     @Author: Ankitha B L
#     @Date: 6-12-2024
#     @Last Modified by: Ankitha B L
#     @Last Modified time: 6-12-2024
#     @Title : python program for Seaborn Swarm plots
# '''

# %% [markdown]
# ### Q1. Write a program to draw a swarm plot of total bill against size for a given dataset

# %%
import pandas as pd
import seaborn as sns

# %%
def draw_swarm_plot():
    """ 
    Description :
        This function is to draw a swarm plot of total bill against size for a given dataset
    Return :
        It returns swarm plot of total bill against size for a given dataset
    """
    dataset = pd.read_csv('tips.csv')
    sns.catplot(x='size',y='total_bill',data=dataset,hue='sex',kind='swarm',s=15)
    
    
def main():
    draw_swarm_plot()
    
    
if __name__ == "__main__":
    main()

# %% [markdown]
# ### Q2. Write a program to draw swarm plot of “total bill” against day for a dataset

# %%
def generate_swarm_plot():
    """ 
    Description :
        This function is to draw swarm plot of “total bill” against day for a dataset
    Return :
        It returns swarm plot of total bill against day for a given dataset
    """
    dataset = pd.read_csv('tips.csv')
    sns.catplot(x='day',y='total_bill',hue='sex',data=dataset,kind='swarm')
    
    
def main():
    generate_swarm_plot()
    
    
if __name__ == "__main__":
    main()
